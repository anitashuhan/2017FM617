# %% [markdown]
# # Q1寫一個函式，抓取 Google Finance 的股價歷史資料

# %%
import requests

# %%
url = "http://finance.google.com/finance/historical"

# %%
params = {}
params['q'] = 'AAPL'
params['startdate'] = '2016-01-01'
params['output'] = 'csv'

# %%
r = requests.get(url, params=params)

# %%
import io
import pandas

# %%
df = pandas.read_csv(io.StringIO(r.content.decode('utf-8')))

# %%
print(df)
# Out:
#           Date    Open    High     Low   Close     Volume
# 0     6-Dec-17  167.50  170.20  166.46  169.01   28560000
# 1     5-Dec-17  169.06  171.52  168.40  169.64   27350154
# 2     4-Dec-17  172.48  172.62  169.63  169.80   32542385
# 3     1-Dec-17  169.95  171.67  168.50  171.05   39759288
# 4    30-Nov-17  170.43  172.14  168.44  171.85   41527218
# 5    29-Nov-17  172.63  172.92  167.16  169.48   41666364
# 6    28-Nov-17  174.30  174.87  171.86  173.07   26428802
# 7    27-Nov-17  175.05  175.08  173.34  174.09   20716802
# 8    24-Nov-17  175.10  175.50  174.65  174.97   14026673
# 9    22-Nov-17  173.36  175.00  173.05  174.96   25588925
# 10   21-Nov-17  170.78  173.70  170.78  173.14   25131295
# 11   20-Nov-17  170.29  170.56  169.56  169.98   16262447
# 12   17-Nov-17  171.04  171.39  169.64  170.15   21899544
# 13   16-Nov-17  171.18  171.87  170.30  171.10   23637484
# 14   15-Nov-17  169.97  170.32  168.38  169.08   29158070
# ...

# %% [markdown]
# # Q2抓取台股歷史資料，並繪製價量圖形

# %%
import pandas_datareader.data as web
from datetime import datetime

# %%
import kchart

# %%
r1=web.DataReader('2912.tw','yahoo',datetime(2017,1,4),datetime(2017,12,5))

# %%
kchart.draw(r1,'統一超(2912)')
